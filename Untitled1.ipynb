# %% [markdown]
# <a href="https://colab.research.google.com/github/bism-tn/NSALAb/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np

data=load_iris()
data.data.shape
print('classes to predict:',data.target_names)
X=data.data
y=data.target
display(X.shape,y.shape)





X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5,random_state=0)
cls=DecisionTreeClassifier()
y_pred=cls.fit(X_train,y_train).predict(X_test)
from sklearn.metrics import accuracy_score
print('train data',accuracy_score(y_true=y_train,y_pred=classifier.predict(X_train)))
print('test data',accuracy_score(y_true=y_train,y_pred=y_pred))
from sklearn.tree import export_graphviz
from six import StringIO
import IPython
from Ipython.display import Image
dot_data=StringIO()
export graphviz(cls, out_file=dot_data,filled=True,rounded=true,special_characters=True,feature_names=data.feature_names,class_names=data.feature_names)
graph=pydotplus.graph_from_dot_data()dot_data.getvalue())
Image(graph.create_png())
# Out:
#   File "<ipython-input-4-e4e45dd48816>", line 29
#     export graphviz(cls, out_file=dot_data,filled=True,rounded=true,special_characters=True,feature_names=data.feature_names,class_names=data.feature_names)
#                   ^
# SyntaxError: invalid syntax

# %%
# Out:
# classes to predict: ['setosa' 'versicolor' 'virginica']
# (150, 4)
# (150,)
# train data Accuracy 100.0
# test data Accuracy 33.33333333333333
